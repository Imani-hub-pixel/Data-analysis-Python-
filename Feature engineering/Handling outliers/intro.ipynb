# %%
#Minimum value,maximum,median,Q1,Q2,IQR
import numpy as np

# %%
list_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(list_marks,[0,0.25,0.50,0.75,1])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
#IQR=Q3-Q1
IQR=Q3-Q1
IQR
# Out:
# np.float64(35.0)

# %%
lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

print("Lower fence:",lower_fence)
print("Upper fence:",upper_fence)
# Out:
# Lower fence: 1.5
# Upper fence: 141.5

# %%
import seaborn as sns
sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks=[-100,-200,1,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,1300,1200,1000]

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >
